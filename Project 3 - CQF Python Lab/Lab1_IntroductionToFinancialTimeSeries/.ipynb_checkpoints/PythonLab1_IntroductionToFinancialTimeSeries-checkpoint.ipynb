# %%
# Import data manipulation libraries
import numpy as np
import pandas as pd
        
# Import yahoo finance library
import yfinance as yf

# Import cufflinks for visualization
import cufflinks as cf
cf.set_config_file(offline=True, theme='pearl')

# Machine info & package version
from watermark import watermark
# %load_ext watermark
# %watermark -a "Sun Yufei" -u -d -v -m -iv

# Ignore warnings - optional
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>
# Author: Sun Yufei
#
# Last updated: 2025-03-09
#
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.15.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit
#
# yfinance : 0.2.54
# numpy    : 1.23.5
# watermark: 2.5.0
# cufflinks: 0.17.3
# pandas   : 2.0.0

# %% [markdown]
# # Data Retrieval

# %% [markdown]
# ## Retrieving end-of-day data for single security

# %%
# Fetch the data by specifying the number of period
df1 = yf.download('SPY', period='5d', progress=False)

# Display the first five rows of the dataframe to check the results. 
df1
# Out:
# YF.download() has changed argument auto_adjust default to True
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2025-03-03  583.770020  597.340027  579.900024  596.179993   74249200
# 2025-03-04  576.859985  585.390015  572.250000  579.710022  109648200
# 2025-03-05  583.059998  584.880005  573.080017  576.690002   71230500
# 2025-03-06  572.710022  580.169983  570.119995  575.479980   80094900
# 2025-03-07  575.919983  577.390015  565.630005  570.900024   81042900

# %%
# Fetch data by specifying the the start and end dates
df2 = yf.download('SPY', start='2022-06-01', end='2022-06-30', progress=False)

# Display the first five rows of the dataframe to check the results. 
df2.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2022-06-01  393.206665  399.590664  390.653060  398.563485  86585800
# 2022-06-02  400.694641  400.742629  390.758630  393.043436  79609600
# 2022-06-03  394.118622  397.478624  393.129822  395.904209  71874300
# 2022-06-06  395.318695  399.945876  394.128274  398.189088  57508900
# 2022-06-07  399.110596  399.571406  391.305787  391.776207  59272400

# %%
# Fetch data for year to date (YTD)
df3 = yf.download('SPY', period='ytd', progress=False)

# Display the last five rows of the dataframe to check the results. 
df3.tail()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2025-03-03  583.770020  597.340027  579.900024  596.179993   74249200
# 2025-03-04  576.859985  585.390015  572.250000  579.710022  109648200
# 2025-03-05  583.059998  584.880005  573.080017  576.690002   71230500
# 2025-03-06  572.710022  580.169983  570.119995  575.479980   80094900
# 2025-03-07  575.919983  577.390015  565.630005  570.900024   81042900

# %% [markdown]
# ## Retrieving data for multiple securities

# %%
# Specify stocks
# https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average
dow_stocks = ['UNH', 'GS', 'HD', 'AMGN', 'MCD']

# Fetch data for multiple stocks at once
#  2025-03-06  381.730011  387.760010  380.730011  383.500000  4222000
#  2025-03-07  376.799988  380.649994  368.899994  379.500000  4573900
#
#  [250 rows x 5 columns],
#  'AMGN': Price            Close        High         Low        Open   Volume
#  Ticker            AMGN        AMGN        AMGN        AMGN     AMGN
#  Date
#  2024-03-08  265.652069  268.378943  263.963550  264.739873  2250800
#  2024-03-11  267.214447  269.960748  264.914560  266.389615  1851000
#  2024-03-12  268.359528  269.921887  266.030529  268.660355  1738700
#  2024-03-13  267.825775  270.319758  267.068850  269.950994  1641000
#  2024-03-14  263.507446  269.029130  262.449694  268.650652  2370500
#  ...                ...         ...         ...         ...      ...
#  2025-03-03  310.779999  312.480011  307.339996  307.339996  2970700
#  2025-03-04  312.190002  319.820007  312.100006  316.529999  3820000
#  2025-03-05  316.570007  318.940002  310.140015  310.630005  2629000
#  2025-03-06  317.820007  318.679993  312.500000  316.420013  3076500
#  2025-03-07  324.859985  328.190002  317.779999  318.950012  3944200
#
#  [250 rows x 5 columns],
#  'MCD': Price            Close        High         Low        Open   Volume
#  Ticker             MCD         MCD         MCD         MCD      MCD
#  Date
#  2024-03-08  285.604309  286.512252  281.972628  283.153921  2481800
#  2024-03-11  287.820465  288.435513  284.940491  285.213842  2893300
#  2024-03-12  287.322479  289.323796  286.570771  288.659948  2233100
#  2024-03-13  276.144379  286.502494  275.890572  285.321230  5441300
#  2024-03-14  275.041199  275.812421  271.233768  275.714819  4659300
#  ...                ...         ...         ...         ...      ...
#  2025-03-03  304.290009  309.489990  302.429993  308.109985  4371300
#  2025-03-04  305.769989  312.929993  304.589996  304.589996  3954500
#  2025-03-05  307.450012  308.459991  303.369995  304.000000  2327500
#  2025-03-06  310.369995  311.350006  304.380005  307.799988  2954900
#  2025-03-07  321.290009  323.170013  310.350006  310.820007  7606700
#
#  [250 rows x 5 columns]}

# %%
# Display GS stock data
ohlcv['GS'].head()
# Out:
# Price            Close        High         Low        Open   Volume
# Ticker              GS          GS          GS          GS       GS
# Date
# 2024-03-08  378.637238  387.080973  378.363282  380.339702  1657200
# 2024-03-11  377.825195  378.069799  373.187512  377.345781  1654200
# 2024-03-12  379.801605  380.731113  375.496580  379.253695  1703900
# 2024-03-13  383.842438  386.718984  379.801574  380.515829  2370600
# 2024-03-14  380.222321  387.824634  377.130552  385.916710  3029500

# %%
# Display GS adjusted close data
ohlcv['GS']['Close']
# Out:
# Ticker              GS
# Date
# 2024-03-08  378.637238
# 2024-03-11  377.825195
# 2024-03-12  379.801605
# 2024-03-13  383.842438
# 2024-03-14  380.222321
# ...                ...
# 2025-03-03  605.260010
# 2025-03-04  581.140015
# 2025-03-05  593.070007
# 2025-03-06  567.669983
# 2025-03-07  559.669983
#
# [250 rows x 1 columns]

# %% [markdown]
# ## Retrieving intraday data

# %%
# Retrieve intraday data for last five days
df6 = yf.download('SPY', period='5d', interval='1m', progress=False)

# Display dataframe
df6
# Out:
# Price                           Close        High         Low        Open
# Ticker                            SPY         SPY         SPY         SPY
# Datetime
# 36   0.01 -0.020000     -66.666670    113.0          1418           0.199227
# 37   0.01 -0.020000     -66.666670     56.0           430           0.203133
# 38   0.01  0.010000     100.000000     24.0          2156           0.210945
# 39   0.01  0.000000       0.000000    517.0          1733           0.214852
# 40   0.01  0.000000       0.000000    799.0          1723           0.222664
# 41   0.01 -0.010000     -50.000000    765.0          1568           0.226570
# 42   0.01 -0.010000     -50.000000    701.0           674           0.234383
# 43   0.01 -0.010000     -50.000000   3030.0           559           0.238289
# 44   0.01  0.000000       0.000000   1618.0           501           0.246101
# 45   0.01 -0.010000     -50.000000      4.0           236           0.250007
# 46   0.01  0.000000       0.000000      2.0           132           0.257820
# 47   0.01  0.000000       0.000000    150.0           180           0.261726
# 48   0.01  0.000000       0.000000      2.0           239           0.269539
# 49   0.01 -0.010000     -50.000000     18.0           313           0.273445
# 50   0.01  0.000000       0.000000    439.0           751           0.281257
# 51   0.01  0.000000       0.000000   2758.0           918           0.285163
# 52   0.01  0.020000     200.000000      3.0           575           0.312507
# 53   0.01  0.000000       0.000000    154.0           227           0.343757
# 54   0.01 -0.010000     -50.000000    259.0           308           0.367194
# 55   0.01  0.000000       0.000000      1.0           133           0.394537
# 56   0.01  0.000000       0.000000     30.0           900           0.421881
# 57   0.01  0.000000       0.000000      NaN             2           0.445318
# 58   0.01  0.000000       0.000000      NaN             1           0.562504
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD
# 40       False      REGULAR      USD
# 41       False      REGULAR      USD
# 42       False      REGULAR      USD
# 43       False      REGULAR      USD
# 44       False      REGULAR      USD
# 45       False      REGULAR      USD
# 46       False      REGULAR      USD
# 47       False      REGULAR      USD
# 48       False      REGULAR      USD
# 49       False      REGULAR      USD
# 50       False      REGULAR      USD
# 51       False      REGULAR      USD
# 52       False      REGULAR      USD
# 53       False      REGULAR      USD
# 54       False      REGULAR      USD
# 55       False      REGULAR      USD
# 56       False      REGULAR      USD
# 57       False      REGULAR      USD
# 58       False      REGULAR      USD  , puts=        contractSymbol             lastTradeDate  strike  lastPrice    bid
# 0   SPY250311P00500000 2025-03-07 21:06:17+00:00   500.0       0.02   0.01  \
# 1   SPY250311P00510000 2025-03-07 19:41:38+00:00   510.0       0.03   0.02
# 2   SPY250311P00515000 2025-03-07 19:05:14+00:00   515.0       0.02   0.02
# 3   SPY250311P00520000 2025-03-07 20:49:46+00:00   520.0       0.04   0.03
# 4   SPY250311P00525000 2025-03-07 21:04:27+00:00   525.0       0.03   0.03
# ..                 ...                       ...     ...        ...    ...
# 56  SPY250311P00613000 2025-03-06 15:02:33+00:00   613.0      38.20  36.72
# 57  SPY250311P00614000 2025-03-07 20:51:56+00:00   614.0      38.75  37.72
# 58  SPY250311P00615000 2025-02-27 15:38:18+00:00   615.0      20.22  38.72
# 59  SPY250311P00616000 2025-02-27 15:38:18+00:00   616.0      21.19  39.72
# 60  SPY250311P00620000 2025-02-25 15:19:15+00:00   620.0      27.77  43.72
#
#       ask     change  percentChange  volume  openInterest  impliedVolatility
# 0    0.02  -0.030000     -60.000004   734.0          1239           0.539067  \
# 1    0.03  -0.050000     -62.500000  2404.0          1209           0.503911
# 2    0.03  -0.080000     -79.999990   150.0           284           0.468755
# 3    0.04  -0.050000     -55.555557   109.0          1070           0.445318
# 4    0.04  -0.080000     -72.727270   144.0          1063           0.408209
# ..    ...        ...            ...     ...           ...                ...
# 56  37.95   0.200001       0.526318     1.0             0           0.478765
# 57  38.94  13.280001      52.139780     2.0             1           0.486822
# 58  39.95   0.000000       0.000000     NaN             0           0.497564
# 59  40.95   0.000000       0.000000     NaN             0           0.506841
# 60  44.94   0.000000       0.000000     NaN             0           0.542241
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# ..         ...          ...      ...
# 56        True      REGULAR      USD
# 57        True      REGULAR      USD
# 58        True      REGULAR      USD
# 59        True      REGULAR      USD
# 60        True      REGULAR      USD
#
# [61 rows x 14 columns], underlying={'language': 'en-US', 'region': 'US', 'quoteType': 'ETF', 'typeDisp': 'ETF', 'quoteSourceName': 'Delayed Quote', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'longName': 'SPDR S&P 500 ETF Trust', 'regularMarketPrice': 575.92, 'marketState': 'CLOSED', 'currency': 'USD', 'exchange': 'PCX', 'messageBoardId': 'finmb_6160262', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'gmtOffSetMilliseconds': -14400000, 'market': 'us_market', 'esgPopulated': False, 'corporateActions': [], 'postMarketTime': 1741395592, 'shortName': 'SPDR S&P 500', 'regularMarketTime': 1741381200, 'regularMarketChangePercent': 0.560486, 'hasPrePostMarketData': True, 'firstTradeDateMilliseconds': 728317800000, 'priceHint': 2, 'postMarketChangePercent': -0.18579097, 'postMarketPrice': 574.85, 'postMarketChange': -1.0700073, 'regularMarketChange': 3.20996, 'regularMarketDayHigh': 577.39, 'regularMarketDayRange': '565.63 - 577.39', 'regularMarketDayLow': 565.63, 'regularMarketVolume': 76139972, 'regularMarketPreviousClose': 572.71, 'bid': 574.65, 'ask': 574.9, 'bidSize': 8, 'askSize': 9, 'fullExchangeName': 'NYSEArca', 'financialCurrency': 'USD', 'regularMarketOpen': 570.9, 'averageDailyVolume3Month': 53336327, 'averageDailyVolume10Day': 73153180, 'fiftyTwoWeekLowChange': 82.06, 'fiftyTwoWeekLowChangePercent': 0.16616045, 'fiftyTwoWeekRange': '493.86 - 613.23', 'fiftyTwoWeekHighChange': -37.309998, 'fiftyTwoWeekHighChangePercent': -0.06084177, 'fiftyTwoWeekLow': 493.86, 'fiftyTwoWeekHigh': 613.23, 'fiftyTwoWeekChangePercent': 12.6427765, 'trailingAnnualDividendRate': 5.662, 'trailingPE': 25.521145, 'trailingAnnualDividendYield': 0.00988633, 'dividendYield': 1.19, 'ytdReturn': 1.43002, 'trailingThreeMonthReturns': -0.99021, 'trailingThreeMonthNavReturns': -0.99021, 'netAssets': 634082230000.0, 'epsTrailingTwelveMonths': 22.566385, 'sharesOutstanding': 917782016, 'bookValue': 429.22, 'fiftyDayAverage': 596.3728, 'fiftyDayAverageChange': -20.45282, 'fiftyDayAverageChangePercent': -0.03429536, 'twoHundredDayAverage': 571.98004, 'twoHundredDayAverageChange': 3.9399414, 'twoHundredDayAverageChangePercent': 0.00688825, 'netExpenseRatio': 0.0945, 'marketCap': 528569008128, 'priceToBook': 1.3417827, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'tradeable': False, 'cryptoTradeable': False, 'symbol': 'SPY'})

# %%
# Filter calls for strike above 390
df7 = options.calls[options.calls['strike']>390]

# Check the filtered output
df7.iloc[:,:7]
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice    bid
# 0   SPY250311C00560000 2025-03-07 20:45:41+00:00   560.0      18.00  16.47  \
# 1   SPY250311C00565000 2025-03-07 21:06:26+00:00   565.0      11.83  12.20
# 2   SPY250311C00570000 2025-03-07 21:14:26+00:00   570.0       8.32   8.42
# 3   SPY250311C00571000 2025-03-07 21:14:24+00:00   571.0       7.59   7.73
# 4   SPY250311C00572000 2025-03-07 21:14:27+00:00   572.0       7.00   7.07
# 5   SPY250311C00573000 2025-03-07 21:14:29+00:00   573.0       6.38   6.44
# 6   SPY250311C00574000 2025-03-07 21:09:33+00:00   574.0       5.88   5.84
# 7   SPY250311C00575000 2025-03-07 21:14:33+00:00   575.0       5.21   5.26
# 8   SPY250311C00576000 2025-03-07 21:14:49+00:00   576.0       4.71   4.71
# 9   SPY250311C00578000 2025-03-07 21:14:40+00:00   578.0       3.68   3.70
# 10  SPY250311C00579000 2025-03-07 21:14:41+00:00   579.0       3.23   3.25
# 11  SPY250311C00580000 2025-03-07 21:14:53+00:00   580.0       2.85   2.83
# 12  SPY250311C00581000 2025-03-07 21:14:36+00:00   581.0       2.40   2.43
# 13  SPY250311C00582000 2025-03-07 21:14:59+00:00   582.0       2.10   2.07
# 50  SPY250311C00619000 2025-03-07 18:08:17+00:00   619.0       0.01   0.00
# 51  SPY250311C00620000 2025-03-07 18:11:46+00:00   620.0       0.01   0.00
# 52  SPY250311C00625000 2025-03-06 18:59:01+00:00   625.0       0.03   0.00
# 53  SPY250311C00630000 2025-03-07 17:42:20+00:00   630.0       0.01   0.00
# 54  SPY250311C00635000 2025-03-07 17:34:21+00:00   635.0       0.01   0.00
# 55  SPY250311C00640000 2025-03-05 17:53:14+00:00   640.0       0.01   0.00
# 56  SPY250311C00645000 2025-03-05 17:00:27+00:00   645.0       0.02   0.00
# 57  SPY250311C00650000 2025-02-26 15:49:26+00:00   650.0       0.02   0.00
# 58  SPY250311C00680000 2025-02-26 15:20:12+00:00   680.0       0.01   0.00
#
#       ask    change
# 0   16.61  2.100000
# 1   12.32 -0.420000
# 2    8.50 -0.980001
# 3    7.81 -1.059999
# 4    7.14 -1.060000
# 5    6.50 -1.270000
# 6    5.89 -1.050000
# 7    5.31 -1.220000
# 8    4.76 -1.230000
# 9    3.75 -1.330000
# 10   3.29 -1.330000
# 11   2.86 -1.280000
# 12   2.47 -1.320000
# 13   2.10 -1.290000
# 14   1.78 -1.290000
# 15   1.48 -1.130000
# 16   1.21 -1.210000
# 17   0.98 -1.160000
# 18   0.77 -1.110000
# 19   0.60 -1.050000
# 20   0.46 -0.930000
# 21   0.33 -0.850000
# 22   0.25 -0.750000
# 23   0.18 -0.620000
# 24   0.13 -0.550000
# 25   0.09 -0.460000
# 26   0.06 -0.340000
# 27   0.04 -0.290000
# 28   0.03 -0.240000
# 29   0.02 -0.180000
# 30   0.02 -0.140000
# 31   0.02 -0.100000
# 32   0.02 -0.070000
# 33   0.02 -0.050000
# 34   0.01 -0.030000
# 35   0.01 -0.030000
# 36   0.01 -0.020000
# 37   0.01 -0.020000
# 38   0.01  0.010000
# 39   0.01  0.000000
# 40   0.01  0.000000
# 41   0.01 -0.010000
# 42   0.01 -0.010000
# 43   0.01 -0.010000
# 44   0.01  0.000000
# 45   0.01 -0.010000
# 46   0.01  0.000000
# 47   0.01  0.000000
# 48   0.01  0.000000
# 49   0.01 -0.010000
# 50   0.01  0.000000
# 51   0.01  0.000000
# 52   0.01  0.020000
# 53   0.01  0.000000
# 54   0.01 -0.010000
# 55   0.01  0.000000
# 56   0.01  0.000000
# 57   0.01  0.000000
# 58   0.01  0.000000

# %% [markdown]
# ## Retrieving Hypertext Markup Language (HTML)
#
# We'll now retrieve India's benchmark index NIFTY50 Index data from Wikipedia.

# %%
# Read data from wikipedia
nifty50 = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1].Symbol.to_list()

# Read five symbols
nifty50[:50]
# Out:
# ['ADANIENT',
#  'ADANIPORTS',
#  'APOLLOHOSP',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BEL',
#  'BPCL',
#  'BHARTIARTL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBILIFE',
#  'SHRIRAMFIN',
#  'SBIN',
#  'SUNPHARMA',
#  'TCS',
#  'TATACONSUM',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TECHM',
#  'TITAN',
#  'TRENT',
#  'ULTRACEMCO',
#  'WIPRO']

# %% [markdown]
# ## Retrieving JSON requests
#
# We'll now retrieve json requests from the web and manipualte it using pandas.

# %% [markdown]
# ```
# import requests
# from src.creds import *
#
# # Read json request from the alphavantage
# url = f'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey={av_apikey}'
# r = requests.get(url)
# data = r.json()
#
# # Manipulate into dataframe
# df9 = pd.DataFrame.from_records(data['Time Series (5min)']).T
#
# # Verify the top five rows
# df9.head()
# ```

# %% [markdown]
# # Data Storage

# %% [markdown]
# ## Storing OHLCV data in Excel File

# %%
# Dataframe to Excel
from pandas import ExcelWriter

# %%
# Storing the fetched data in a separate sheet for each security
writer = ExcelWriter('stocks.xlsx')

# df.to_excel() - this is list comprehension
[pd.DataFrame(ohlcv[symbol].tz_localize(None)).to_excel(writer, symbol) for symbol in dow_stocks]

writer.close()

# %% [markdown]
# ## Storing OHLCV data in a CSV File

# %%
# Save ohlcv data for each securities in stockname.csv format
[pd.DataFrame(ohlcv[symbol]).to_csv(''+symbol+'.csv') for symbol in dow_stocks]
print('*** file saved ***')
# Out:
# *** file saved ***

# %% [markdown]
# ## Storing Nifty50 data in SQLite Database

# %%
# Import & create database 
import sqlalchemy
engine = sqlalchemy.create_engine('sqlite:///India')

# %%
# fetch the data from yahoo
data = [yf.download(symbol+'.NS', period='1y', progress=False).reset_index() for symbol in nifty50] 

# save it to database
for frame, symbol in zip(data, nifty50):
    frame.to_sql(symbol, engine, if_exists='replace', index=False)

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Excel / CSV

# %%
# Reading the fetched data in a spreadsheet
gs = pd.read_excel('stocks.xlsx', sheet_name='GS', index_col=0, parse_dates=True)

# Display the last five rows of the data frame to check the results
gs.tail()
# Out:
#                           Close        High         Low        Open   Volume
# Price
# 2025-03-03 00:00:00   605.26001  628.780029  598.320007  622.400024  3152300
# 2025-03-04 00:00:00  581.140015         600  567.570007   595.97998  4061000
# 2025-03-05 00:00:00  593.070007  597.119995  576.780029  582.090027  2600600
# 2025-03-06 00:00:00  567.669983  586.710022  564.619995  580.590027  4332300
# 2025-03-07 00:00:00  559.669983  568.169983  544.909973  568.169983  4069600

# %%
# Read CSV file  
gs = pd.read_csv('GS.csv', index_col=0, parse_dates=True)

# Display the last five rows of the data frame to check the results
gs.tail()
# Out:
#                         Close               High                Low
# Price
# 2025-03-03   605.260009765625   628.780029296875  598.3200073242188  \
# 2025-03-04  581.1400146484375              600.0  567.5700073242188
# 2025-03-05  593.0700073242188  597.1199951171875   576.780029296875
# 2025-03-06  567.6699829101562  586.7100219726562  564.6199951171875
# 2025-03-07  559.6699829101562  568.1699829101562  544.9099731445312
#
#                          Open   Volume
# Price
# 2025-03-03  622.4000244140625  3152300
# 2025-03-04    595.97998046875  4061000
# 2025-03-05  582.0900268554688  2600600
# 2025-03-06  580.5900268554688  4332300
# 2025-03-07  568.1699829101562  4069600

# %% [markdown]
# ## SQL

# %%
# Query from database
result = pd.read_sql_query('SELECT * FROM  "ADANIENT" WHERE "DATE"> "2023-01-01"', engine)

# Display the results
result.tail()
# Out:
#                    ('Date', '')  ('Close', 'ADANIENT.NS')
# 243  2025-03-03 00:00:00.000000               2117.100098  \
# 244  2025-03-04 00:00:00.000000               2144.800049
# 245  2025-03-05 00:00:00.000000               2245.850098
# 246  2025-03-06 00:00:00.000000               2252.850098
# 247  2025-03-07 00:00:00.000000               2247.500000
#
#      ('High', 'ADANIENT.NS')  ('Low', 'ADANIENT.NS')  ('Open', 'ADANIENT.NS')
# 243              2127.250000             2026.550049              2109.000000  \
# 244              2154.000000             2080.000000              2085.100098
# 245              2258.399902             2148.050049              2153.949951
# 246              2268.899902             2226.149902              2260.000000
# 247              2267.649902             2227.000000              2249.949951
#
#      ('Volume', 'ADANIENT.NS')
# 243                    1592611
# 244                     852978
# 245                    1370106
# 246                     890270
# 247                     818806

# %% [markdown]
# # Data Manipulation

# %%
# Load csv file, specify dayfirst
data = pd.read_csv('spy.csv', index_col=0, parse_dates=True, dayfirst=True)['2011':'2021']
data['Change'] = 100.*np.log(data['Adj Close']).diff().fillna(0)

# %%
# subset selection
data.filter(['Open', 'Close']).head()
# Out:
#                   Open       Close
# Date
# 2011-01-03  126.709999  127.050003
# 2011-01-04  127.330002  126.980003
# 2011-01-05  126.580002  127.639999
# 2011-01-06  127.690002  127.389999
# 2011-01-07  127.559998  127.139999

# %%
# drop columns
data.drop('Volume', axis=1).head()
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2011-01-03  126.709999  127.599998  125.699997  127.050003  105.443665  \
# 2011-01-04  127.330002  127.370003  126.190002  126.980003  105.385559
# 2011-01-05  126.580002  127.720001  126.459999  127.639999  105.933296
# 2011-01-06  127.690002  127.830002  127.010002  127.389999  105.725830
# 2011-01-07  127.559998  127.769997  126.150002  127.139999  105.518341
#
#               Change
# Date
# 2011-01-03  0.000000
# 2011-01-04 -0.055121
# 2011-01-05  0.518400
# 2011-01-06 -0.196038
# 2011-01-07 -0.196445

# %%
# drop rows
data.drop(data.index[-1], axis=0).tail()
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2020-04-22  278.350006  281.000000  276.910004  279.100006  279.100006  \
# 2020-04-23  280.489990  283.940002  278.750000  279.079987  279.079987
# 2020-04-24  280.730011  283.700012  278.500000  282.970001  282.970001
# 2020-04-27  285.119995  288.269989  284.619995  287.049988  287.049988
# 2020-04-28  291.019989  291.399994  285.399994  285.730011  285.730011
#
#                Volume    Change
# Date
# 2020-04-22   93524600  2.195183
# 2020-04-23  104709700 -0.007173
# 2020-04-24   85166000  1.384246
# 2020-04-27   77896600  1.431548
# 2020-04-28  105270000 -0.460903

# %% [markdown]
# ## Resampling data

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases
# Resampling to derive weekly values from daily time series
df_weekly = df4[['GS']].resample('W').last()

# Display the last five rows of the data frame to check the output
df_weekly.tail()
# Out:
# Ticker              GS
# Date
# 2025-02-09  652.663696
# 2025-02-16  657.290710
# 2025-02-23  622.513123
# 2025-03-02  622.289978
# 2025-03-09  559.669983

# %%
# Resampling to a specific day of the week: Thu
df_weekly_thu = df4[['GS']].resample('W-THU').last()

# Display the last five rows of the data frame to check the output
df_weekly_thu.tail()
# Out:
# Ticker              GS
# Date
# 2025-02-13  645.747986
# 2025-02-20  639.091003
# 2025-02-27  605.000000
# 2025-03-06  567.669983
# 2025-03-13  559.669983

# %%
# Resampling to derive monthly values from daily time series
df_monthly = df4[['GS']].resample('M').last()

# Display the last five rows of the data frame to check the output
df_monthly.tail()
# Out:
# Ticker              GS
# Date
# 2025-01-31  637.240173
# 2025-02-28  622.289978
# 2025-03-31  559.669983

# %%
# Create a copy of spy dataframe & reset index
df = data.copy()
df.reset_index(inplace=True)

# Assign separate columns for month & year 
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Verify the output
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 2341 2020-04-23  280.489990  283.940002  278.750000  279.079987  279.079987  \
# 2342 2020-04-24  280.730011  283.700012  278.500000  282.970001  282.970001
# 2343 2020-04-27  285.119995  288.269989  284.619995  287.049988  287.049988
# 2344 2020-04-28  291.019989  291.399994  285.399994  285.730011  285.730011
# 2345 2020-04-29  291.529999  294.880005  290.410004  293.209991  293.209991
#
#          Volume    Change  Year  Month
# 2341  104709700 -0.007173  2020      4
# 2342   85166000  1.384246  2020      4
# 2343   77896600  1.431548  2020      4
# 2344  105270000 -0.460903  2020      4
# 2345  118745600  2.584170  2020      4

# %% [markdown]
# ## Min-Max Index
#
# We'll now use idxmax and idxmin to select the index value that corresponds to the maximum or minimum of the index's percentage change for each year.

# %%
# Grouping dataframe to get the max and min values
max_min = {'Change': ['idxmax', 'idxmin']}
df.groupby(['Year']).agg(max_min).T
# Out:
# Year           2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# Change idxmax   151   376   502   997  1169  1276  1549  2008  2014  2320
#        idxmin   150   356   619   775  1167  1378  1603  1784  2160  2314

# %%
# Check the results for year 2020
df.loc[[2314, 2320]]
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 2314 2020-03-16  241.179993  256.899994  237.360001  239.850006  238.447861  \
# 2320 2020-03-24  234.419998  244.100006  233.800003  243.149994  243.149994
#
#          Volume     Change  Year  Month
# 2314  297240000 -11.588651  2020      3
# 2320  235494500   8.673099  2020      3

# %%
# Check the year wise maximum values
df.loc[df.groupby('Year')['Change'].idxmax()]
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 151  2011-08-09  114.070000  117.639999  110.269997  117.480003   98.410210  \
# 376  2012-06-29  135.199997  136.270004  134.850006  136.100006  116.429924
# 502  2013-01-02  145.110001  146.149994  144.729996  146.059998  126.508362
# 997  2014-12-18  204.740005  212.970001  203.919998  206.779999  185.264771
# 1169 2015-08-26  192.080002  194.789993  188.369995  194.460007  176.826218
# 1276 2016-01-29  190.020004  193.880005  189.880005  193.720001  178.122925
# 1549 2017-03-01  238.389999  240.320007  238.369995  239.779999  225.208954
# 2008 2018-12-26  235.970001  246.179993  233.759995  246.179993  240.192596
# 2014 2019-01-04  247.589996  253.110001  247.169998  252.389999  246.251556
# 2320 2020-03-24  234.419998  244.100006  233.800003  243.149994  243.149994
#
#          Volume    Change  Year  Month
# 151   717828700  4.545085  2011      8
# 376   212250900  2.462113  2012      6
# 502   192059000  2.530732  2013      1
# 997   257633900  2.442778  2014     12
# 1169  339257000  3.767491  2015      8
# 1276  210529300  2.408504  2016      1
# 1549  149158200  1.390048  2017      3
# 2008  218485400  4.928991  2018     12
# 2014  142628800  3.294686  2019      1
# 2320  235494500  8.673099  2020      3

# %%
# Assign a new dataframe with pivoted values
newdf = pd.pivot_table(df,
                       index='Month',
                       columns='Year',
                       values='Change',
                       aggfunc=np.sum)

# Analysing year wise statistics for Nasdaq returns
newdf
# Out:
# Year        2011      2012      2013      2014      2015      2016      2017
# Month
# 1       1.274784  4.533136  4.992305 -3.588473 -3.007705 -5.106875  1.773661  \
# 2       3.414754  4.248981  1.267803  4.451037  5.468188 -0.082632  3.853910
# 3       0.011998  3.165745  3.726805  0.826168 -1.583016  6.510019  0.124926
# 4       2.855019 -0.669807  1.903029  0.692748  0.978560  0.393356  0.987726
# 5      -1.127797 -6.193473  2.333515  2.294073  1.277444  1.686869  1.401414
# 6      -1.701373  3.977941 -1.343450  2.043497 -2.052125  0.346964  0.635470
# 7      -2.020734  1.175972  5.038632 -1.352872  2.233782  3.582183  2.034585
# 8      -5.654439  2.474413 -3.045153  3.870440 -6.288668  0.119692  0.291349
# 9      -7.194807  2.503478  3.115593 -1.389190 -2.584711  0.005795  1.994914
# 10     10.359135 -1.836561  4.526635  2.327743  8.163496 -1.748908  2.329048
# 11     -0.407198  0.564365  2.920717  2.710161  0.364831  3.617617  3.010823
# 12      1.039410  0.889483  2.559633 -0.253985 -1.743334  2.006900  1.205499
#
# Year       2018      2019       2020
# Month
# 1      5.482797  7.702185  -0.040389
# 2     -3.703775  3.190132  -8.247524
# 3     -2.779308  1.793888 -13.338431
# 4      0.515485  4.003994  12.889892
# 5      2.401825 -6.589541        NaN
# 6      0.573456  6.727210        NaN
# 7      3.637674  1.500635        NaN
# 8      3.142087 -1.688510        NaN
# 9      0.592783  1.927090        NaN
# 10    -7.160778  2.186400        NaN
# 11     1.837927  3.555840        NaN
# 12    -9.216842  2.864133        NaN

# %%
# Summary statistics
newdf.describe()
# Out:
# Year        2011       2012       2013       2014       2015       2016
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000  \
# mean    0.070729   1.236139   2.333005   1.052612   0.102229   0.944248
# std     4.491635   3.062620   2.447942   2.365709   3.921519   2.921839
# min    -7.194807  -6.193473  -3.045153  -3.588473  -6.288668  -5.106875
# 25%    -1.781213   0.255822   1.744223  -0.528706  -2.185271  -0.016312
# 50%    -0.197600   1.825193   2.740175   1.434833  -0.609092   0.370160
# 75%     1.669843   3.368794   3.926763   2.423347   1.516529   2.400721
# max    10.359135   4.533136   5.038632   4.451037   8.163496   6.510019
#
# Year        2017       2018       2019       2020
# count  12.000000  12.000000  12.000000   4.000000
# mean    1.636944  -0.389722   2.264455  -2.184113
# std     1.101624   4.463040   3.696918  11.445595
# min     0.124926  -9.216842  -6.589541 -13.338431
# 25%     0.899662  -3.010425   1.720574  -9.520251
# 50%     1.587538   0.583120   2.525266  -4.143957
# 75%     2.108201   2.586890   3.667879   3.192181
# max     3.853910   5.482797   7.702185  12.889892

# %% [markdown]
# # Interactive Visualization of Time Series
#
# We use `cufflinks` for interactive visualization. It is one of the most feature rich third-party wrapper around `Plotly` by Santos Jorge. It binds the power of `plotly` with the flexibility of `pandas` for easy plotting.
#
# When you import cufflinks library, all pandas data frames and series objects have a new method `.iplot()` attached to them which is similar to pandas' built-in `.plot()` method.

# %% [markdown]
# ## Plotting Line Chart
#
# Next, we'll plot the time series data in the line format.

# %%
cf.set_config_file(theme='pearl')

# %%
df2[['Close']].tail(30).iplot(
    layout=dict(
        title='Line Chart',
        xaxis=dict(title=dict(text='Date')),
        yaxis=dict(title=dict(text='Close Price'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="576eea51-9d00-4916-9c20-f85f6d79e3b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("576eea51-9d00-4916-9c20-f85f6d79e3b5")) {                    Plotly.newPlot(                        "576eea51-9d00-4916-9c20-f85f6d79e3b5",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"('Close', 'SPY')","text":"","x":["2022-06-01","2022-06-02","2022-06-03","2022-06-06","2022-06-07","2022-06-08","2022-06-09","2022-06-10","2022-06-13","2022-06-14","2022-06-15","2022-06-16","2022-06-17","2022-06-21","2022-06-22","2022-06-23","2022-06-24","2022-06-27","2022-06-28","2022-06-29"],"y":{"dtype":"f8","bdata":"AAAAgE6TeEAAAABAHQt5QAAAAODloXhAAAAAYBm1eEAAAAAAxfF4QAAAAMBXrHhAAAAAIB8WeEAAAADAVGN3QAAAACABgHZAAAAAwKVudkAAAAAAhMB2QAAAAEC\u002f\u002f3VAAAAAYOMLdkAAAAAA95l2QAAAAMB5j3ZAAAAAABfIdkAAAADgg4F3QAAAAKCHandAAAAAIAvwdkAAAADgQut2QA=="},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"sc ...

# %% [markdown]
# ## Plotting OHLC Data
#
# Next, we'll plot the time series data in ohlc format.

# %%
df2.columns = ['_'.join(col) if isinstance(col, tuple) else col for col in df2.columns]
print(df2.columns)
df2[-30:].iplot(
    kind='ohlc',
    title='OHLC Chart',
    layout=dict(
        xaxis=dict(title=dict(text='Date')),
        yaxis=dict(title=dict(text='Price'))
    )
)
# Out:
# Index(['Close_SPY', 'High_SPY', 'Low_SPY', 'Open_SPY', 'Volume_SPY'], dtype='object')
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0
 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"HD","text":"","x":["2025-01-02","2025-01-03","2025-01-06","2025-01-07","2025-01-08","2025-01-10","2025-01-13","2025-01-14","2025-01-15","2025-01-16","2025-01-17","2025-01-21","2025-01-22","2025-01-23","2025-01-24","2025-01-27","2025-01-28","2025-01-29","2025-01-30","2025-01-31","2025-02-03","2025-02-04","2025-02-05","2025-02-06","2025-02-07","2025-02-10","2025-02-11","2025-02-12","2025-02-13","2025-02-14","2025-02-18","2025-02-19","2025-02-20","2025-02-21","2025-02-24","2025-02-25","2025-02-26","2025-02-27","2025-02-28","2025-03-03","2025-03-04","2025-03-05","2025-03-06","2025-03-07"],"y":{"dtype":"f8","bdata":"..."},"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"title":{"text":"GS vs HD"},"xaxis":{"title":{"text":"Date"}},"yaxis":{"title":{"text":"GS Price"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %% [markdown]
# ## Plotting using Subplots

# %%
# Use subplots
df4[['GS', 'HD']].iplot(
    subplots=True,
    shape=(2, 1),
    shared_xaxes=True,
    layout=dict(
        title='GS & HD Subplots',
        xaxis=dict(title=dict(text='Date')),
        yaxis=dict(title=dict(text='Price'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="0b0223f9-1725-46c0-aecf-a47b52fe5a84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("0b0223f9-1725-46c0-aecf-a47b52fe5a84")) {                    Plotly.newPlot(                        "0b0223f9-1725-46c0-aecf-a47b52fe5a84",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"GS","text":"","x":["2025-01-02","2025-01-03","2025-01-06","2025-01-07","2025-01-08","2025-01-10","2025-01-13","2025-01-14","2025-01-15","2025-01-16","2025-01-17","2025-01-21","2025-01-22","2025-01-23","2025-01-24","2025-01-27","2025-01-28","2025-01-29","2025-01-30","2025-01-31","2025-02-03","2025-02-04","2025-02-05","2025-02-06","2025-02-07","2025-02-10","2025-02-11","2025-02-12","2025-02-13","2025-02-14","2025-02-18","2025-02-19","2025-02-20","2025-02-21","2025-02-24","2025-02-25","2025-02-26","2025-02-27","2025-02-28","2025-03-03","2025-03-04","2025-03-05","2025-03-06","2025-03-07"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAQBDhgUAAAADgIwqCQAAAAIAXJIJAAAAAgA8KgkAAAADAQwmCQAAAACDlaYFAAAAA4GCBgUAAAAAArsWBQAAAACBx14JAAAAAILkPg0AAAADgz3aDQAAAAEDdvINAAAAAIN2sg0AAAADAweKDQAAAAEAPzoNAAAAAID6xg0AAAABAOdWDQAAAAGDh0YNAAAAAoBwUhEAAAADg6+mDQAAAAID\u002fqYNAAAAAIGi4g0AAAABAHxKEQAAAAADHd4RAAAAAQE9lhEAAAADAjzqEQAAAAABfIIRAAAAAwGEuhEAAAADg+y2EQAAAAGBTioRAAAAAgPzmhEAAAACA08aEQAAAAGC6+INAAAAA4Bp0g0AAAACAZ3iDQAAAAOABH4NAAAAAQMY1g0AAAAAAAOiCQAAAAOBRcoNAAAAAgBTqgkAAAADAHimCQAAAAGCPiIJAAAAAIFy9gUAAAAAgXH2BQA=="},"yaxis":"y","type":"scatter"},{"line":{"color":"rgba(55, 128, 191, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":
# %% [markdown]
# ## Visualising Return Series
#
# We'll now plot historical daily log normal return series using just one line of code.

# %%
# Calculating Log Normal Returns
# Use numpy log function to derive log normal returns
daily_returns = np.log(df4).diff().dropna()

# Display the last five rows of the data frame to check the output
daily_returns.head()
# Out:
# Ticker          AMGN        GS        HD       MCD       UNH
# Date
# 2025-01-03  0.007454  0.008934  0.001852  0.007730  0.016688
# 2025-01-06 -0.010119  0.005604  0.000488 -0.008859  0.001305
# 2025-01-07  0.013330 -0.005621 -0.013289 -0.009768  0.001129
# 2025-01-08  0.008171 -0.000172  0.007700 -0.008469  0.019774
# 2025-01-10 -0.007522 -0.035126  0.006923 -0.016128 -0.007329

# %% [markdown]
# ## Plotting Annual Returns

# %%
# Plot Mean Annual Returns
(daily_returns.mean() * 252 * 100).iplot(
    kind='bar',
    layout=dict(
        title='Annualized Returns (%)',
        xaxis=dict(title=dict(text='Assets')),
        yaxis=dict(title=dict(text='Annualized Return (%)'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="fa8a856e-0470-4137-a148-d98f112d6ef9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("fa8a856e-0470-4137-a148-d98f112d6ef9")) {                    Plotly.newPlot(                        "fa8a856e-0470-4137-a148-d98f112d6ef9",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["AMGN","GS","HD","MCD","UNH"],"y":{"dtype":"f8","bdata":"NzxYhYsbYUC6uTGMc9ApwClMVogz3DHANgRMWJEvTUBRGUv41OgpwA=="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolargl"}],"scatterpolar":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolar"}],"scatter":[{"fillpattern":{"fill ...

# %% [markdown]
# ## Plotting Annualized Volatility

# %%
# Plot Mean Annualized Volatility
(daily_returns.std() * np.sqrt(252) * 100).iplot(
    kind='bar',
    layout=dict(
        title='Annualized Volatility (%)',
        xaxis=dict(title=dict(text='Assets')),
        yaxis=dict(title=dict(text='Annualized Volatility (%)'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="82646664-902c-42c0-9880-4d95400004b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("82646664-902c-42c0-9880-4d95400004b2")) {                    Plotly.newPlot(                        "82646664-902c-42c0-9880-4d95400004b2",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"None","orientation":"v","text":"","x":["AMGN","GS","HD","MCD","UNH"],"y":{"dtype":"f8","bdata":"9toRjQwaOUAamhAvCHY\u002fQPYlYc1NnTZAf\u002fSYlLVnNEAJC3q6BD5BQA=="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergl"}],"scattermapbox":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermapbox"}],"scattermap":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattermap"}],"scatterpolargl":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolargl"}],"scatterpolar":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatterpolar"}],"scatter":[{"fillpatte ...

# %% [markdown]
# ## Plotting Rolling Returns

# %%
# To calculate 5 days rolling returns, simply sum daily returns for 5 days as log returns are additive
rolling_return = daily_returns.rolling(5).sum().dropna()

# Display the last five rows of the data frame to check the output
rolling_return.head()
# Out:
# Ticker          AMGN        GS        HD       MCD       UNH
# Date
# 2025-01-10  0.011313 -0.026381  0.003675 -0.035493  0.031567
# 2025-01-13  0.033762 -0.030061  0.000000 -0.038559  0.053402
PwAwC0PwsnM\u002fABThK\u002fP9fT8AXIICgMKDPwBwC7+HcnY\u002fABDjJtqPV78AXJ1NYFB3vwAqlvF4xIk\u002fAGVZMUKqkz8Afb6tRH2YPwDQzZEI\u002fpw\u002fAMUtgKDflD8AIN6kYnd2PwCiRMczDI2\u002fAGhyiZTvfD8Ad\u002fTuE8WgP4BthfKDR6A\u002fAOR3rUthhb8AbmfiFMOiv4CSWsQwZKu\u002fACJw9fjMtr9A2gULzBG0v4Ax71MoEay\u002fAIC0eP9+N78AEZRFLqqdv4Bo\u002fFspY6q\u002fgERrbeVbor8AR\u002fEX302wv4CUmvSsJru\u002f"},"type":"scatter"},{"line":{"color":"rgba(50, 171, 96, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"HD","text":"","x":["2025-01-10","2025-01-13","2025-01-14","2025-01-15","2025-01-16","2025-01-17","2025-01-21","2025-01-22","2025-01-23","2025-01-24","2025-01-27","2025-01-28","2025-01-29","2025-01-30","2025-01-31","2025-02-03","2025-02-04","2025-02-05","2025-02-06","2025-02-07","2025-02-10","2025-02-11","2025-02-12","2025-02-13","2025-02-14","2025-02-18","2025-02-19","2025-02-20","2025-02-21","2025-02-24","2025-02-25","2025-02-26","2025-02-27","2025-02-28","2025-03-03","2025-03-04","2025-03-05","2025-03-06","2025-03-07"],"y":{"dtype":"f8","bdata":"AIBE5f0Zbj8AAAAAAAAAAACKVo2X24E\u002fACU6LKpUrD8AUM\u002fzA3WsPwAno4yU+ag\u002fAB0Dcj2Nsj+AqEVw8BemPwD7T8\u002fnt5Q\u002fACDkFoO0iT8APQtZ7wOjPwAAmJIsT08\u002fAFyi9VaDgD8AwGzCVWQxPwDIUOld+ni\u002fAMxJKZfKo78APZVozhqSvwBg\u002fQ9CsE8\u002fAEA\u002fWaLjSr8AoEpgzQuHvwCmtXSUCYo\u002fACKhJIgYiD8ABNDBH6qQvwD40EI9JXG\u002fANTA1WBcdT8AXYeyecOavwBVqkY7aKq\u002fAEU+rXnun79AlTAxWWuxvwDaI0jNg7G\u002fAFfBSxPDmb8AJhtTcsyJvwDCFD8Pzoa\u002fAMehmImZnT8AO6nmtEiTPwDpBzATr56\u002fAL5Vb8rGhb8AxCTm\u002fKeWvwB1D1OvOKq\u002f"},"type":"scatter"},{"line":{"color":"rgba(128, 0, 128, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"MCD","text":"","x":["2025-01- ...

# %% [markdown]
# # Time Series Statistics
#
# Statistics is a branch of mathematics that deals with collecting, interpreting, organization and interpretation of data. The two main categories of statistics are descriptive statistics and inferential statistics.
#
# Descriptive statistics help us to understand the data in a meaningful way and is an important part of data analysis. While inferential statistics allows us to infer trends and derive conclusion from it.

# %%
# Analysing the daily returns data
daily_returns.describe().T
# Out:
#         count      mean       std       min       25%       50%       75%
# Ticker
# AMGN     43.0  0.005431  0.015813 -0.033128 -0.003414  0.006323  0.012188  \
# GS       43.0 -0.000512  0.019819 -0.043772 -0.008231 -0.000077  0.012285
# HD       43.0 -0.000709  0.014246 -0.023952 -0.013000  0.000122  0.007823
# MCD      43.0  0.002316  0.012854 -0.020977 -0.006948  0.002554  0.006811
# UNH      43.0 -0.000514  0.021723 -0.074350 -0.010241  0.001129  0.013677
#
#              max
# Ticker
# AMGN    0.062987
# GS      0.058431
# HD      0.033325
# MCD     0.046863
# UNH     0.038523

# %% [markdown]
# ## Log Normal Distribution
#
# A normal distribution is the most common and widely used distribution in statistics. It is popularly referred as a “bell curve” or “Gaussian curve”. Financial time series though random in short term, follows a log normal distribution on a longer time frame.
#
# Now that we have derived the daily log returns, we will plot this return distribution and check whether the stock returns follows log normality.

# %%
# Plot log normal distribution of returns
daily_returns.iplot(
    kind='histogram',
    title='Histogram of Daily Returns',
    subplots=True,
    layout=dict(
        xaxis=dict(title=dict(text='Daily Return')),
        yaxis=dict(title=dict(text='Frequency'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="f0ef1ca6-ec68-4392-8f87-839547fb370b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("f0ef1ca6-ec68-4392-8f87-839547fb370b")) {                    Plotly.newPlot(                        "f0ef1ca6-ec68-4392-8f87-839547fb370b",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"AMGN","opacity":0.8,"orientation":"v","x":[0.00745446977033648,-0.010119266356516832,0.013329725437657203,0.008170688266060822,-0.0075221823242195285,0.029903446293928937,-0.011502220076405223,0.006865081054431066,0.0018203510572964987,0.009897729880116835,0.00987360426739503,-0.004997687310662968,0.01610715374522176,-0.00889213132672051,0.02697293305451698,-0.009409824160051983,0.004911278473243463,0.008272917244847022,0.004917170851046038,0.012014917361068633,0.000519150389487244,0.06298689710009864,-0.03312774462712298,-0.014341058038675136,0.004249349728830509,0.006323455180787363,-0.005408015607839545,0.006452367811109916,-0.011711589862193783,0.005616783568765271,0.005007935513681616,0.01236085908953033,0.016907305494136438,0.02190282696601109,0.01890198949852362,-0.02974447943669567,-0.0018294599922139554,0.00729784374176301,0.008790701159507641,0.004526722208355594,0.013932424663399168,0.003940798527194644,0.021909067370041058],"xaxis":"x","yaxis":"y","type":"histogram"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(55, 128, 191, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"GS","opacity":0.8,"orientation":"v","x":[0.008934426060646317,0.0056037741775547545,-0.005621008502896707,-0.0001723595915983367,-0.035125776410023235,0.005253995779909815,0.015126150448504738,0.05843092709361386,0.011600726350930124,0.020905907085559505,0.013960869603236503,-0.0031716418223979304,0.010642889818913481,-0.004073943160379123,-0.00569995275589541,0.007111968868365182,-0.0006586991598842573,0.012968949339903446,-0.0082419479761624,-0.012618376692574707,0.0028581874110944483,0.01761496060053691,0.01959134904140214,-0.003530759810057127,-0.008220926441310894,-0.005070304253558255,0.0027155899347661716,-0.00007702964250899669,0.01771708940731287,0.017468239338786162,-0.006028269689220878,-0.039519512323889394,-0.026282151069927373,0.0008629259210612972,-0.018098124904169843,0.0046403010488687,-0.015941352567003797,0.028177728685969683,-0.027748052802230916,-0.040666417027991564,0.020320731339036335,-0.04377221436292622,-0.014192940080430816],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(50, 171, 96, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"HD","opacity":0.8,"orientation":"v","x":[0.0018517603033219032,0.00048809311709518965,-0.013288675617273427,0.0077000267186306814,0.006923298699544667,-0.001822742917997111,0.00920771286882971,0.033325145315138194,0.007946842984805969,0.00012218810355602017,0.021865762414338796,-0.020108547116054254,0.010406547448369885,0.0002653798459730794,0.024710253712091124,-0.014318150678881203,-0.013001019757826526,0.0026089167246166056,-0.00609814342628745,-0.007846620514201597,0.006656484118057193,0.005646419617381326,0.0008212670656044807,-0.016530530043276315,0.01611994396255234,0.0057084401099434245,-0.022393092847353024,0.012909334028413433,-0.007129573353059193,-0.01523141233698766,-0.019731729085814997,-0.0019997678263585783,-0.02395177409373961,-0.0075027037728787604,0.028027758780397427,-0.007170495243406627,-0.0005380005833419688,0.01608945234430248,-0.017576673959570854,-0.020769015497296373,0.012161168159056324,-0.012030128978593346,-0.012999070893264353],"xaxis":"x3","yaxis":"y3","type":"histogram"},{"histfunc":"count","histnorm":"","marker":{"color":"rgba(128, 0, 128, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"MCD","opacity":0.8,"orientation":"v","x":[0.007730423700193612,-0.008859293798338719,-0.009767594663721901,-0.008468750965809235,-0.016127997224235635,0.0046648727871456686,-0.00725399 ...

# %% [markdown]
# ## Correlation
#
# Correlation defines the similarity between two random variables. As an example we will check correlation between our Nasdaq listed stocks.

# %%
# Plot correlation of returns
daily_returns.corr().iplot(
    kind='heatmap',
    title='Correlation Matrix',
    colorscale='Blues',
    layout=dict(
        xaxis=dict(title=dict(text='Assets')),
        yaxis=dict(title=dict(text='Assets'))
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.0.min.js"></script>                <div id="79d6e468-321d-433d-88c3-86443385d3ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                if (document.getElementById("79d6e468-321d-433d-88c3-86443385d3ca")) {                    Plotly.newPlot(                        "79d6e468-321d-433d-88c3-86443385d3ca",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":["AMGN","GS","HD","MCD","UNH"],"y":["AMGN","GS","HD","MCD","UNH"],"z":{"dtype":"f8","bdata":"AAAAAAAA8D9bVgn0CgOkv+jjWffB6sg\u002fWV7VW9U40D+coxY7zAvGP1tWCfQKA6S\u002fAAAAAAAA8D+Glt9ohTjbPyEM8TDyAcG\u002feLDrzpwmkb\u002fo41n3werIP4aW32iFONs\u002fAAAAAAAA8D+ipSqT\u002f5\u002fSP5VtmZC3+dU\u002fWV7VW9U40D8hDPEw8gHBv6KlKpP\u002fn9I\u002fAAAAAAAA8D9OCz2QHvPTP5yjFjvMC8Y\u002feLDrzpwmkb+VbZmQt\u002fnVP04LPZAe89M\u002fAAAAAAAA8D8=","shape":"5, 5"},"zmax":1.0,"zmin":-0.1328718890164007,"type":"heatmap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker" ...

# %% [markdown]
# ## Pairwise Correlation

# %%
# Compute pairwise correlation
daily_returns.corrwith(daily_returns['GS'])
# Out:
# Ticker
# AMGN   -0.039086
# GS      1.000000
# HD      0.425325
# MCD    -0.132872
# UNH    -0.016749
# dtype: float64
